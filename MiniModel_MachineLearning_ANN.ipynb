# %% [markdown]
# #Training & Testing Model Klasifikasi IRIS

# %% [markdown]
# ## **1.Pendahuluan**

# %% [markdown]
# Artificial Neural Network (ANN) merupakan salah satu model pembelajaran mesin yang meniru cara kerja jaringan saraf manusia. Pada laporan ini, dibuat sebuah model ANN untuk melakukan klasifikasi data bunga Iris berdasarkan empat fitur: sepal length, sepal width, petal length, dan petal width. Dataset yang digunakan adalah IRIS.csv.
#
# Tujuan:
#
# *   Melakukan Preprocessing data
# *   Melatih model ANN
# *   Menguji Performa model menggunakan data uji
# *   Melakukan prediksi pada data baru

# %% [markdown]
# ##  **2. Import Library**

# %% [markdown]
# Pada tahap awal dilakukan Import library yang digunakan untuk:
#
# *   Pandas      → Membaca dan memanipulasi data tabular
# *   Numpy        → Operasi matematika dan manipulasi array (matriks)
# *   Scikit-learn → membagi data (train_test_split) dan mengubah skala data (StandardScaler), serta encoding label (LabelBinarizer)
# *   Tensorflow   → Framework utama untuk mengidentifikasi, mengkompilasi, dan melatih model jaringan saraf Tiruan (ANN)

# %%
#import library
import pandas as pd #inport pandas untuk membaca data dalam bentuk tabel
import numpy as np #inport numpy untuk operasi matematika

#scikit-Learn: untuk membagi data dan mengubah skala angka - komputer tdk bisa baca teks
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelBinarizer

#tensorFlow: framework - membuat neural network
import tensorflow as tf
from tensorflow.keras.models import Sequential  #untuk menumpuk layer
from tensorflow.keras.layers import Dense       #layer neuron biasa (terhubung penuh)
from tensorflow.keras.layers import Dropout     #layer pemutus hubungan (pencegah hafalan)
from tensorflow.keras.optimizers import Adam    #algoritma optimasi (mekanik perbaikan bobot)

# %% [markdown]
# ##  **3.Pra-Pemrosesan Data**

# %% [markdown]
# ### **3.1 Membaca Data**

# %% [markdown]
#   Pandas → Digunakan untuk membaca Dataset dari file IRIS.csv.

# %%
# Membaca data dari file IRIS.csv
data = pd.read_csv('IRIS.csv')
print(data) #untuk uji hasil output
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### **3.2 Memisahkan Fitur dan Label**

# %% [markdown]
# *   Empat Kolom Pertama → Sebagai Input (X_Input)
# *    Kolom ke-5 → sebgai label (y_output)

# %%
#memisahkan data (input-x) dan label (output-y)
x_input = data.values #mengambil semua nilai pada data
print(x_input)
x_input = np.delete(x_input, 4, axis=1) #menghapus kolom ke-4 (kolom label)
print(x_input) #-- tetsing hasil data x

#mengambil kolom label
y_output = data.values[:, 4] #mengambil semua baris (:,) pada kolom ke 4
print(y_output) #-- testing hasil data y
# Out:
# [[5.1 3.5 1.4 0.2 'Iris-setosa']
#  [4.9 3.0 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.3 0.2 'Iris-setosa']
#  [4.6 3.1 1.5 0.2 'Iris-setosa']
#  [5.0 3.6 1.4 0.2 'Iris-setosa']
#  [5.4 3.9 1.7 0.4 'Iris-setosa']
#  [4.6 3.4 1.4 0.3 'Iris-setosa']
#  [5.0 3.4 1.5 0.2 'Iris-setosa']
#  [4.4 2.9 1.4 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [5.4 3.7 1.5 0.2 'Iris-setosa']
#  [4.8 3.4 1.6 0.2 'Iris-setosa']
#  [4.8 3.0 1.4 0.1 'Iris-setosa']
#  [4.3 3.0 1.1 0.1 'Iris-setosa']
#  [5.8 4.0 1.2 0.2 'Iris-setosa']
#  [5.7 4.4 1.5 0.4 'Iris-setosa']
#  [5.4 3.9 1.3 0.4 'Iris-setosa']
#  [5.1 3.5 1.4 0.3 'Iris-setosa']
#  [5.7 3.8 1.7 0.3 'Iris-setosa']
#  [5.1 3.8 1.5 0.3 'Iris-setosa']
#  [5.4 3.4 1.7 0.2 'Iris-setosa']
#  [5.1 3.7 1.5 0.4 'Iris-setosa']
#  [4.6 3.6 1.0 0.2 'Iris-setosa']
#  [5.1 3.3 1.7 0.5 'Iris-setosa']
#  [4.8 3.4 1.9 0.2 'Iris-setosa']
#  [5.0 3.0 1.6 0.2 'Iris-setosa']
#  [5.0 3.4 1.6 0.4 'Iris-setosa']
#  [5.2 3.5 1.5 0.2 'Iris-setosa']
#  [5.2 3.4 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.6 0.2 'Iris-setosa']
#  [4.8 3.1 1.6 0.2 'Iris-setosa']
#  [5.4 3.4 1.5 0.4 'Iris-setosa']
#  [5.2 4.1 1.5 0.1 'Iris-setosa']
#  [5.5 4.2 1.4 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [5.0 3.2 1.2 0.2 'Iris-setosa']
#  [5.5 3.5 1.3 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [4.4 3.0 1.3 0.2 'Iris-setosa']
#  [5.1 3.4 1.5 0.2 'Iris-setosa']
#  [5.0 3.5 1.3 0.3 'Iris-setosa']
#  [4.5 2.3 1.3 0.3 'Iris-setosa']
#  [4.4 3.2 1.3 0.2 'Iris-setosa']
#  [5.0 3.5 1.6 0.6 'Iris-setosa']
#  [5.1 3.8 1.9 0.4 'Iris-setosa']
#  [4.8 3.0 1.4 0.3 'Iris-setosa']
#  [5.1 3.8 1.6 0.2 'Iris-setosa']
#  [4.6 3.2 1.4 0.2 'Iris-setosa']
#  [5.3 3.7 1.5 0.2 'Iris-setosa']
#  [5.0 3.3 1.4 0.2 'Iris-setosa']
#  [7.0 3.2 4.7 1.4 'Iris-versicolor']
#  [6.4 3.2 4.5 1.5 'Iris-versicolor']
#  [6.9 3.1 4.9 1.5 'Iris-versicolor']
#  [5.5 2.3 4.0 1.3 'Iris-versicolor']
#  [6.5 2.8 4.6 1.5 'Iris-versicolor']
#  [5.7 2.8 4.5 1.3 'Iris-versicolor']
#  [6.3 3.3 4.7 1.6 'Iris-versicolor']
#  [4.9 2.4 3.3 1.0 'Iris-versicolor']
#  [6.6 2.9 4.6 1.3 'Iris-versicolor']
#  [5.2 2.7 3.9 1.4 'Iris-versicolor']
#  [5.0 2.0 3.5 1.0 'Iris-versicolor']
#  [5.9 3.0 4.2 1.5 'Iris-versicolor']
#  [6.0 2.2 4.0 1.0 'Iris-versicolor']
#  [6.1 2.9 4.7 1.4 'Iris-versicolor']
#  [5.6 2.9 3.6 1.3 'Iris-versicolor']
#  [6.7 3.1 4.4 1.4 'Iris-versicolor']
#  [5.6 3.0 4.5 1.5 'Iris-versicolor']
#  [5.8 2.7 4.1 1.0 'Iris-versicolor']
#  [6.2 2.2 4.5 1.5 'Iris-versicolor']
#  [5.6 2.5 3.9 1.1 'Iris-versicolor']
#  [5.9 3.2 4.8 1.8 'Iris-versicolor']
#  [6.1 2.8 4.0 1.3 'Iris-versicolor']
#  [6.3 2.5 4.9 1.5 'Iris-versicolor']
#  [6.1 2.8 4.7 1.2 'Iris-versicolor']
#  [6.4 2.9 4.3 1.3 'Iris-versicolor']
#  [6.6 3.0 4.4 1.4 'Iris-versicolor']
#  [6.8 2.8 4.8 1.4 'Iris-versicolor']
#  [6.7 3.0 5.0 1.7 'Iris-versicolor']
#  [6.0 2.9 4.5 1.5 'Iris-versicolor']
#  [5.7 2.6 3.5 1.0 'Iris-versicolor']
#  [5.5 2.4 3.8 1.1 'Iris-versicolor']
#  [5.5 2.4 3.7 1.0 'Iris-versicolor']
#  [5.8 2.7 3.9 1.2 'Iris-versicolor']
#  [6.0 2.7 5.1 1.6 'Iris-versicolor']
#  [5.4 3.0 4.5 1.5 'Iris-versicolor']
#  [6.0 3.4 4.5 1.6 'Iris-versicolor']
#  [6.7 3.1 4.7 1.5 'Iris-versicolor']
#  [6.3 2.3 4.4 1.3 'Iris-versicolor']
#  [5.6 3.0 4.1 1.3 'Iris-versicolor']
#  [5.5 2.5 4.0 1.3 'Iris-versicolor']
#  [5.5 2.6 4.4 1.2 'Iris-versicolor']
#  [6.1 3.0 4.6 1.4 'Iris-versicolor']
#  [5.8 2.6 4.0 1.2 'Iris-versicolor']
#  [5.0 2.3 3.3 1.0 'Iris-versicolor']
#  [5.6 2.7 4.2 1.3 'Iris-versicolor']
#  [5.7 3.0 4.2 1.2 'Iris-versicolor']
#  [5.7 2.9 4.2 1.3 'Iris-versicolor']
#  [6.2 2.9 4.3 1.3 'Iris-versicolor']
#  [5.1 2.5 3.0 1.1 'Iris-versicolor']
#  [5.7 2.8 4.1 1.3 'Iris-versicolor']
#  [6.3 3.3 6.0 2.5 'Iris-virginica']
#  [5.8 2.7 5.1 1.9 'Iris-virginica']
#  [7.1 3.0 5.9 2.1 'Iris-virginica']
#  [6.3 2.9 5.6 1.8 'Iris-virginica']
#  [6.5 3.0 5.8 2.2 'Iris-virginica']
#  [7.6 3.0 6.6 2.1 'Iris-virginica']
#  [4.9 2.5 4.5 1.7 'Iris-virginica']
#  [7.3 2.9 6.3 1.8 'Iris-virginica']
#  [6.7 2.5 5.8 1.8 'Iris-virginica']
#  [7.2 3.6 6.1 2.5 'Iris-virginica']
#  [6.5 3.2 5.1 2.0 'Iris-virginica']
#  [6.4 2.7 5.3 1.9 'Iris-virginica']
#  [6.8 3.0 5.5 2.1 'Iris-virginica']
#  [5.7 2.5 5.0 2.0 'Iris-virginica']
#  [5.8 2.8 5.1 2.4 'Iris-virginica']
#  [6.4 3.2 5.3 2.3 'Iris-virginica']
#  [6.5 3.0 5.5 1.8 'Iris-virginica']
#  [7.7 3.8 6.7 2.2 'Iris-virginica']
#  [7.7 2.6 6.9 2.3 'Iris-virginica']
#  [6.0 2.2 5.0 1.5 'Iris-virginica']
#  [6.9 3.2 5.7 2.3 'Iris-virginica']
#  [5.6 2.8 4.9 2.0 'Iris-virginica']
#  [7.7 2.8 6.7 2.0 'Iris-virginica']
#  [6.3 2.7 4.9 1.8 'Iris-virginica']
#  [6.7 3.3 5.7 2.1 'Iris-virginica']
#  [7.2 3.2 6.0 1.8 'Iris-virginica']
#  [6.2 2.8 4.8 1.8 'Iris-virginica']
#  [6.1 3.0 4.9 1.8 'Iris-virginica']
#  [6.4 2.8 5.6 2.1 'Iris-virginica']
#  [7.2 3.0 5.8 1.6 'Iris-virginica']
#  [7.4 2.8 6.1 1.9 'Iris-virginica']
#  [7.9 3.8 6.4 2.0 'Iris-virginica']
#  [6.4 2.8 5.6 2.2 'Iris-virginica']
#  [6.3 2.8 5.1 1.5 'Iris-virginica']
#  [6.1 2.6 5.6 1.4 'Iris-virginica']
#  [7.7 3.0 6.1 2.3 'Iris-virginica']
#  [6.3 3.4 5.6 2.4 'Iris-virginica']
#  [6.4 3.1 5.5 1.8 'Iris-virginica']
#  [6.0 3.0 4.8 1.8 'Iris-virginica']
#  [6.9 3.1 5.4 2.1 'Iris-virginica']
#  [6.7 3.1 5.6 2.4 'Iris-virginica']
#  [6.9 3.1 5.1 2.3 'Iris-virginica']
#  [5.8 2.7 5.1 1.9 'Iris-virginica']
#  [6.8 3.2 5.9 2.3 'Iris-virginica']
#  [6.7 3.3 5.7 2.5 'Iris-virginica']
#  [6.7 3.0 5.2 2.3 'Iris-virginica']
#  [6.3 2.5 5.0 1.9 'Iris-virginica']
#  [6.5 3.0 5.2 2.0 'Iris-virginica']
#  [6.2 3.4 5.4 2.3 'Iris-virginica']
#  [5.9 3.0 5.1 1.8 'Iris-virginica']]
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.0 3.3 1.4 0.2]
#  [7.0 3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.0 1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1.0]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.0 2.0 3.5 1.0]
#  [5.9 3.0 4.2 1.5]
#  [6.0 2.2 4.0 1.0]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.0 4.5 1.5]
#  [5.8 2.7 4.1 1.0]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.0 1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.0 4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.0 5.0 1.7]
#  [6.0 2.9 4.5 1.5]
#  [5.7 2.6 3.5 1.0]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1.0]
#  [5.8 2.7 3.9 1.2]
#  [6.0 2.7 5.1 1.6]
#  [5.4 3.0 4.5 1.5]
#  [6.0 3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.0 4.1 1.3]
#  [5.5 2.5 4.0 1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.0 4.6 1.4]
#  [5.8 2.6 4.0 1.2]
#  [5.0 2.3 3.3 1.0]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.0 4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.0 1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.0 2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.0 5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.0 5.8 2.2]
#  [7.6 3.0 6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2.0]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.0 5.5 2.1]
#  [5.7 2.5 5.0 2.0]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.0 5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.0 2.2 5.0 1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2.0]
#  [7.7 2.8 6.7 2.0]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.0 1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.0 4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.0 5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2.0]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.0 6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.0 3.0 4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.0 5.2 2.3]
#  [6.3 2.5 5.0 1.9]
#  [6.5 3.0 5.2 2.0]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.0 5.1 1.8]]
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %% [markdown]
# ### **3.3 One-Hot Encoding Label (Encoding Label)**

# %% [markdown]
# *   Karena model ANN tidak dapat memproses label dalam bentuk teks (Iris-setosa, dll.), label output diubah menjadi format numerik One-Hot Encoding.
# *   LabelBinarizer → Label berupa teks (Setosa, Versicolor, Virginica) yang diubah menjadi angka
#
# contoh:
#
#
# 1.   iris - setosa → [1. 0, 0]
# 2.   Iris - versicolor → [0, 1, 0]
#
# 3.   Iris - Virginica → [0, 0, 1]

# %%
#merubah data y (teks) jadi angka (one-hot encoding)
encoder = LabelBinarizer() #fungsi untuk mengubah label (teks) menjadi one-hot encoding
y_encoded = encoder.fit_transform(y_output) #melakukan perubahan

# %% [markdown]
# ### **3.4 Pembagian Data Training dan Testing**

# %% [markdown]
# Data dibagi menjadi set pelatihan (Training) dan pengujian (Testing) untuk evaluasi kinerja model.
#
#
# *   Rasio → 80% data untuk pelatihan (X_training, y_training) dan 20% data untuk pengujian (X_testing, y_testing).
# *   random_state=42 → untuk memastikan pembagian data yang sama setiap kali kode dijalankan.

# %%
# pemrosesan data - memisahkan data latih dan data uji
# X_training: data latih, X_testing: data uji
# y_training: label latih, y_testing: label uji
X_training, X_testing, y_training, y_testing = train_test_split(
    x_input, y_encoded, test_size=0.2, random_state=42 # 20% (0,2) data untuk data uji. Random_state = 42 (label acak)
) #(opsional) -- bisa ubah jumlah data latih dan uji untuk coba" analisis / explore

# %% [markdown]
# ### **3.5 Scaling Data**

# %% [markdown]
# Fitur input (X) diubah skalanya menggunakan StandardScaler (Standardisasi) agar memiliki rata-rata μ = 0 dan deviasi standar σ = 1. Ini penting untuk mempercepat konvergensi pelatihan.
#
# - StandardScaler → digunakan untuk Standarisasi data

# %%
#scaling data - merubah data ke skala standar (rata-rata 0, std 1)
scaler = StandardScaler()
X_training_scaled = scaler.fit_transform(X_training) #menghitung rata-rata & ubah data train
X_testing_scaled = scaler.transform(X_testing)       #merubah data test pakai rata-rata train

# %% [markdown]
# ## **4.Pembuatan Model ANN**

# %% [markdown]
# Model ANN dibangun menggunakan Keras dengan struktur sebagai berikut:
#
#
# *   Dense Input → dengan jumlah neorun 16, dengan layar terhubung penuh pertama. Input_shope=(4,), sesuai dengan jumlah fitur input
# *   Dropout → Mematikan 20% neuron secara acak untuk mencegah *overfitting.*
# *   Dense output → dengan jumlah neuron 3, sesuai dengan jumlah kelas (*Iris-setosa, Iris-versicolor, Iris-virginica*). *softmax *menghasilkan probabilitas kelas.

# %%
#membuat model neural network
model = Sequential([
    #input dan hidden layer awal
    #16 jumlah neuron pada layer
    #activation = Rectified Linear Unit (ReLU)
    #input_shape = (4,): jumlah data input (x)
    Dense(16, activation='relu', input_shape=(4,)),

    #dropout layer
    #memaksa mematikan neuron sebesar 20% untuk melatih model belajar -- bisa coba" rubah besar dropout untuk explore hasil model bljr
    Dropout(0.2),

    #dropout kembali
    Dropout(0.2),

    #---area untuk hidden layer--- (kalau mau nambah hidden layer)


    #output layer
    #3: jumlah kelas output (y)
    #activation = softmax: digunakan di ouput layer untuk multi class
    Dense(3, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## **4.1 Kompilasi Model**

# %% [markdown]
# *   Optimizer → Adam dengan learning rate α = 0.01
# *   Loss Function: Categorical Crossentropy → sesuai untuk masalah klasifikasi multi-kelas dengan *One-Hot Encoding*.
# *   Metrics → Accuracy (Akurasi)

# %%
# aturan kompilasi model
#optimizer = Adam: algoritma optimasi
#learning_rate=0.01: kecepatan model dalam belajar
optimasi = Adam(learning_rate=0.01)

#loss='categorical_crossentropy': fungsi loss untuk multi class
model.compile(optimizer=optimasi, loss='categorical_crossentropy', metrics=['accuracy']) #metrics bisa dirubah atau ditambahkan, misal f1 score, recall, dll

# %% [markdown]
# ## **5. Proses Training dan Testing**

# %% [markdown]
# ### **5.1. Pelatihan Model**
# Model dilatih menggunakan data pelatihan yang telah diskalakan (X_training_scaled, y_training).
#
#
# *   Epochs → 100 kali
# *   Batch Size → 16 sampel per batch sebelum bobot di update.
# *   Validation Split → 20% data pelatihan digunakan sebagai set validasi internal selama proses pelatihan.

# %%
# proses latihan model
print("Latihan....")
history = model.fit(
    X_training_scaled, y_training, #data latih
    validation_split=0.2, #20% data latih disimpan untuk validasi (ujian saat latihan)
    epochs=100, #jumlah latihan model
    batch_size=16, #jumlah batas data yang diproses sebelum bobot diupdate
    verbose=1 #menampilkan progress
)
# Out:
# Latihan....
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2031 - loss: 1.4229 - val_accuracy: 0.6250 - val_loss: 0.9307
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4487 - loss: 1.0017 - val_accuracy: 0.9583 - val_loss: 0.6718
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7217 - loss: 0.7182 - val_accuracy: 0.9167 - val_loss: 0.5130
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7503 - loss: 0.6002 - val_accuracy: 0.9583 - val_loss: 0.4229
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8263 - loss: 0.4909 - val_accuracy: 0.9583 - val_loss: 0.3641
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8302 - loss: 0.4514 - val_accuracy: 0.9167 - val_loss: 0.3295
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8576 - loss: 0.4203 - val_accuracy: 0.9167 - val_loss: 0.3066
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8259 - loss: 0.4167 - val_accuracy: 0.9583 - val_loss: 0.2774
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8019 - loss: 0.3776 - val_accuracy: 0.9583 - val_loss: 0.2581
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9049 - loss: 0.3041 - val_accuracy: 0.9583 - val_loss: 0.2399
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7930 - loss: 0.3436 - val_accuracy: 0.9583 - val_loss: 0.2262
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8924 - loss: 0.3269 - val_accuracy: 1.0000 - val_loss: 0.2184
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9144 - loss: 0.3052 - val_accuracy: 1.0000 - val_loss: 0.2117
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9554 - loss: 0.2161 - val_accuracy: 0.9583 - val_loss: 0.2021
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9317 - loss: 0.2832 - val_accuracy: 0.9583 - val_loss: 0.1891
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9360 - loss: 0.2314 - val_accuracy: 0.9583 - val_loss: 0.1857
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8841 - loss: 0.3059 - val_accuracy: 0.9583 - val_loss: 0.1616
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9247 - loss: 0.2342 - val_accuracy: 1.0000 - val_loss: 0.1519
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9290 - loss: 0.2552 - val_accuracy: 1.0000 - val_loss: 0.1407
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9409 - loss: 0.2001 - val_accuracy: 1.0000 - val_loss: 0.1353
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9278 - loss: 0.2290 - val_accuracy: 1.0000 - val_loss: 0.1438
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9161 - loss: 0.2022 - val_accuracy: 0.9583 - val_loss: 0.1482
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9539 - loss: 0.1805 - val_accuracy: 1.0000 - val_loss: 0.1324
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9557 - loss: 0.1677 - val_accuracy: 1.0000 - val_loss: 0.1203
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8787 - loss: 0.2402 - val_accuracy: 1.0000 - val_loss: 0.1096
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9263 - loss: 0.2032 - val_accuracy: 0.9583 - val_loss: 0.1158
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9305 - loss: 0.1522 - val_accuracy: 0.9583 - val_loss: 0.1090
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9345 - loss: 0.1659 - val_accuracy: 0.9583 - val_loss: 0.1076
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8911 - loss: 0.1992 - val_accuracy: 0.9583 - val_loss: 0.1307
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9241 - loss: 0.2155 - val_accuracy: 0.9583 - val_loss: 0.1123
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9435 - loss: 0.1336 - val_accuracy: 0.9583 - val_loss: 0.0994
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9519 - loss: 0.1609 - val_accuracy: 1.0000 - val_loss: 0.0907
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9454 - loss: 0.1511 - val_accuracy: 0.9583 - val_loss: 0.0938
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9417 - loss: 0.1538 - val_accuracy: 0.9583 - val_loss: 0.1077
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9179 - loss: 0.1576 - val_accuracy: 0.9583 - val_loss: 0.1149
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9771 - loss: 0.1136 - val_accuracy: 0.9583 - val_loss: 0.0968
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9621 - loss: 0.1165 - val_accuracy: 0.9583 - val_loss: 0.0834
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9448 - loss: 0.1641 - val_accuracy: 0.9583 - val_loss: 0.0828
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9253 - loss: 0.1611 - val_accuracy: 0.9583 - val_loss: 0.1020
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9738 - loss: 0.0786 - val_accuracy: 0.9583 - val_loss: 0.1186
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9707 - loss: 0.1435 - val_accuracy: 0.9583 - val_loss: 0.1272
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9579 - loss: 0.1057 - val_accuracy: 0.9583 - val_loss: 0.1084
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9363 - loss: 0.1577 - val_accuracy: 0.9583 - val_loss: 0.1014
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9622 - loss: 0.0848 - val_accuracy: 0.9583 - val_loss: 0.1132
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9683 - loss: 0.0813 - val_accuracy: 0.9583 - val_loss: 0.1309
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9259 - loss: 0.1578 - val_accuracy: 0.9583 - val_loss: 0.1205
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9512 - loss: 0.0986 - val_accuracy: 0.9583 - val_loss: 0.1102
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9613 - loss: 0.1053 - val_accuracy: 0.9583 - val_loss: 0.0930
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9719 - loss: 0.1341 - val_accuracy: 0.9583 - val_loss: 0.0878
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9579 - loss: 0.1211 - val_accuracy: 0.9583 - val_loss: 0.1008
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8979 - loss: 0.1527 - val_accuracy: 0.9583 - val_loss: 0.1308
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9519 - loss: 0.1183 - val_accuracy: 0.9583 - val_loss: 0.1369
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9679 - loss: 0.0866 - val_accuracy: 0.9583 - val_loss: 0.1268
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9501 - loss: 0.1274 - val_accuracy: 0.9583 - val_loss: 0.1166
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8792 - loss: 0.2061 - val_accuracy: 0.9167 - val_loss: 0.1624
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9726 - loss: 0.1131 - val_accuracy: 0.9167 - val_loss: 0.1447
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9573 - loss: 0.1163 - val_accuracy: 0.9583 - val_loss: 0.1078
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9446 - loss: 0.0984 - val_accuracy: 0.9583 - val_loss: 0.0852
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9731 - loss: 0.0911 - val_accuracy: 0.9583 - val_loss: 0.0830
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9638 - loss: 0.0867 - val_accuracy: 0.9583 - val_loss: 0.1001
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9882 - loss: 0.0728 - val_accuracy: 0.9583 - val_loss: 0.0998
# Epoch 62/100
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1319

# %% [markdown]
# ### **5.2. Evaluasi Model**

# %% [markdown]
# Kinerja model diuji menggunakan data pengujian yang sama sekali belum pernah dilihat oleh model (X_testing_scaled, y_testing).

# %%
# evaluasi model
print("Uji evaluasi...")
# menguji model dengan data uji
loss, accuracy = model.evaluate(X_testing_scaled, y_testing)
print(f"Akurasi pada data uji: {accuracy*100:.2f}%")

# %% [markdown]
# ### **5.3. Uji Prediksi Contoh**

# %% [markdown]
# Dua sampel data baru diuji untuk memverifikasi kemampuan klasifikasi model:
#
# *   Sampel 1 (Diduga Iris-setosa): Fitur: [5.1, 3.5, 1.4, 0.2]
# *   Sampel 2 (Diduga Iris-versicolor): Fitur: [5.7, 2.8, 4.5, 1.32]
#
# Setiap sampel diskalakan terlebih dahulu sebelum diprediksi.

# %%
#uji contoh prediksi
#iris setosa
bunga_baru = np.array([[5.1, 3.5, 1.4, 0.2]])
bunga_baru_scaled = scaler.transform(bunga_baru) #proses scaling data baru

prediksi = model.predict(bunga_baru_scaled)
kelas_terpilih = encoder.inverse_transform(prediksi) #mengubah hasil prediksi ke label asli


#iris versicolor
bunga_baru2 = np.array([[5.7,2.8,4.5,1.32]])
bunga_baru2_scaled = scaler.transform(bunga_baru2) #proses scaling data baru

prediksi2 = model.predict(bunga_baru2_scaled)
kelas_terpilih2 = encoder.inverse_transform(prediksi2) #mengubah hasil prediksi ke label asli

print(f"======== Hasil tebakan 1 ========")
print(f"Prediksi Probabilitas: {prediksi}")
print(f"Hasil Tebakan: {kelas_terpilih[0]}\n")

print(f"======== Hasil tebakan 2 ========")
print(f"Prediksi Probabilitas: {prediksi2}")
print(f"Hasil Tebakan: {kelas_terpilih2[0]}")
